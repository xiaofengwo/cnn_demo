# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np

image = mpimg.imread('image/Q.jfif')

# %%
plt.imshow(image)

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
# 3x3 filter for horizontal edge detection
sobel_x = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])
# vertical edge detection
sobel_y = np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])
#strong edge 
sobel_p = np.array([[-1, -2, 1],
                   [0, 0, 0],
                   [1, 2, 1]])

# filter the image using filter2D(grayscale image, bit-depth, kernel)  
filtered_image1 = cv2.filter2D(<YOUR_CODE_HERE>)
filtered_image2 = cv2.filter2D(<YOUR_CODE_HERE>)
filtered_image3 = cv2.filter2D(<YOUR_CODE_HERE>)

f, ax = plt.subplots(1, 3, figsize=(15, 4))
ax[0].set_title('Horizontal edge detection')
ax[0].imshow(filtered_image1, cmap='gray')
ax[1].set_title('Vertical edge detection')
ax[1].imshow(filtered_image2, cmap='gray')
ax[2].set_title('Edge detection')
ax[2].imshow(filtered_image3, cmap='gray')

# %% [markdown]
# Identity

# %%
gray
# Out:
# array([[107, 107, 107, ..., 192, 193, 193],
#        [107, 107, 107, ..., 198, 198, 198],
#        [107, 107, 107, ..., 202, 202, 202],
#        ...,
#        [ 51,  39,  41, ...,  33,  42,   9],
#        [ 35,  77,  79, ...,  17,  20,   0],
#        [ 54,  57,  53, ...,   3,   3,   3]], dtype=uint8)

# %%
image = gray[100:105,200:205]

# %%
filter1 = np.array([[ 0, 0, 0], 
                   [ 0, 1, 0], 
                   [ 0, 0, 0]])

# %%
filtered_image1 = cv2.filter2D(image, -1, filter1)

# %%
print(image)
# Out:
# [[185 186 187 188 189]
#  [184 185 187 189 190]
#  [186 187 188 189 190]
#  [188 188 189 190 189]
#  [190 190 189 189 189]]

# %%
print(filtered_image1)
# Out:
# [[185 186 187 188 189]
#  [184 185 187 189 190]
#  [186 187 188 189 190]
#  [188 188 189 190 189]
#  [190 190 189 189 189]]

# %%
print((image == filtered_image1).all())
# Out:
# True

# %%
plt.imshow(image)

# %% [markdown]
# Box Blur

# %%
image = mpimg.imread('image/bird.jpg')

# %%
filter2 = np.array([[ 1/9, 1/9, 1/9], 
                   [ 1/9, 1/9, 1/9], 
                   [ 1/9, 1/9, 1/9]])

# %%
filtered_image2 = cv2.filter2D(image, -1, filter2)

# %%
plt.imshow(image)

# %%
plt.imshow(filtered_image2)

# %% [markdown]
# ReLU

# %%
def relu (x): return max(0.0, x)
